# %%
import os
import warnings
warnings.filterwarnings('ignore')

import numpy as np

from glob import glob
from pathlib import Path
from tslearn.utils import from_pyts_dataset
from tslearn.clustering import KernelKMeans

INTERVAL = 60

# %%
def dropna(nparray):
    if isinstance(nparray[0], np.ndarray):
        return np.array([dropna(x) for x in nparray])
    else:
        return nparray[~np.isnan(nparray)]

# %%
for direction in ["src", "dst"]:
    for dirname in glob(Path(f'timeseries/pch/20230329/interval_{INTERVAL}_{direction}*').__str__()):
        print("Dir: ", dirname)
        if os.path.exists(os.path.join(dirname, "tslearn_kmeans.npy")):
            continue
        pyts_dataset = np.load(os.path.join(dirname, "pyts_dataset.npy"))
        pyts_dataset = dropna(pyts_dataset)
        print("\tPyts dataset shape: ", pyts_dataset.shape)
        X = from_pyts_dataset(pyts_dataset)
        print("\tTslearn dataset shape: ", X.shape)
        model = KernelKMeans(n_clusters=20, verbose=True, random_state=10, n_jobs=2, max_iter=10, tol=1e-3, kernel_params={"sigma": 1})
        y_pred = model.fit_predict(X)
        np.save(os.path.join(dirname, "tslearn_kmeans.npy"), y_pred)
        print("\tTslearn kmeans shape: ", y_pred.shape)
        del pyts_dataset, model, X, y_pred
# Out:
# Dir:  timeseries\pch\20230329\interval_60_src_feature
# 	Pyts dataset shape:  (1973, 8, 1441)
# 	Tslearn dataset shape:  (1973, 1441, 8)
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed:   29.4s
# [Parallel(n_jobs=2)]: Done 446 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=2)]: Done 796 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=2)]: Done 1246 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=2)]: Done 1796 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=2)]: Done 2446 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=2)]: Done 3196 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=2)]: Done 4046 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=2)]: Done 4996 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=2)]: Done 6046 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=2)]: Done 7196 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=2)]: Done 8446 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=2)]: Done 9796 tasks      | elapsed: 16.7min
# [Parallel(n_jobs=2)]: Done 11246 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=2)]: Done 12796 tasks      | elapsed: 24.7min
# [Parallel(n_jobs=2)]: Done 14446 tasks      | elapsed: 29.0min
# [Parallel(n_jobs=2)]: Done 16196 tasks      | elapsed: 33.6min
# [Parallel(n_jobs=2)]: Done 18046 tasks      | elapsed: 38.4min
# [Parallel(n_jobs=2)]: Done 19996 tasks      | elapsed: 43.5min
# [Parallel(n_jobs=2)]: Done 22046 tasks      | elapsed: 48.5min
# [Parallel(n_jobs=2)]: Done 24196 tasks      | elapsed: 53.9min
# [Parallel(n_jobs=2)]: Done 26446 tasks      | elapsed: 59.0min
# [Parallel(n_jobs=2)]: Done 28796 tasks      | elapsed: 63.0min
# [Parallel(n_jobs=2)]: Done 31246 tasks      | elapsed: 66.7min
# [Parallel(n_jobs=2)]: Done 33796 tasks      | elapsed: 70.8min
# [Parallel(n_jobs=2)]: Done 36446 tasks      | elapsed: 74.1min
# [Parallel(n_jobs=2)]: Done 39196 tasks      | elapsed: 78.4min
# [Parallel(n_jobs=2)]: Done 42046 tasks      | elapsed: 82.6min
# [Parallel(n_jobs=2)]: Done 44996 tasks      | elapsed: 88.5min
# [Parallel(n_jobs=2)]: Done 48046 tasks      | elapsed: 95.9min
# [Parallel(n_jobs=2)]: Done 51196 tasks      | elapsed: 103.7min
# [Parallel(n_jobs=2)]: Done 54446 tasks      | elapsed: 109.6min
# [Parallel(n_jobs=2)]: Done 57796 tasks      | elapsed: 113.1min
# [Parallel(n_jobs=2)]: Done 61246 tasks      | elapsed: 120.0min

# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#      10 print("\tTslearn dataset shape: ", X.shape)
#      11 model = KernelKMeans(n_clusters=20, verbose=True, random_state=10, n_jobs=2, max_iter=10, tol=1e-3, kernel_params={"sigma": 1})
# ---> 12 y_pred = model.fit_predict(X)
#      13 np.save(os.path.join(dirname, "tslearn_kmeans.npy"), y_pred)
#      14 print("\tTslearn kmeans shape: ", y_pred.shape)
#
# File c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\site-packages\tslearn\clustering\kmeans.py:431, in KernelKMeans.fit_predict(self, X, y)
#     411 def fit_predict(self, X, y=None):
#     412     """Fit kernel k-means clustering using X and then predict the closest
#     413     cluster each time series in X belongs to.
#     414
#    (...)
#     429         Index of the cluster each sample belongs to.
#     430     """
# --> 431     return self.fit(X, y).labels_
#
# File c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\site-packages\tslearn\clustering\kmeans.py:360, in KernelKMeans.fit(self, X, y, sample_weight)
#     357 self.n_iter_ = 0
#     359 n_samples = X.shape[0]
# --> 360 K = self._get_kernel(X)
#     361 sw = (sample_weight if sample_weight is not None
#     362       else numpy.ones(n_samples))
#     363 self.sample_weight_ = sw
#
# File c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\site-packages\tslearn\clustering\kmeans.py:277, in KernelKMeans._get_kernel(self, X, Y)
#     275 kernel_params = self._get_kernel_params()
#     276 if self.kernel == "gak":
# --> 277     return cdist_gak(X, Y, n_jobs=self.n_jobs, verbose=self.verbose,
#     278                      **kernel_params)
#     279 else:
#     280     X_sklearn = to_sklearn_dataset(X)
#
# File c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\site-packages\tslearn\metrics\softdtw_variants.py:191, in cdist_gak(dataset1, dataset2, sigma, n_jobs, verbose)
#     140 def cdist_gak(dataset1, dataset2=None, sigma=1., n_jobs=None, verbose=0):
#     141     r"""Compute cross-similarity matrix using Global Alignment kernel (GAK).
#     142
#     143     GAK was originally presented in [1]_.
#    (...)
#     189     .. [1] M. Cuturi, "Fast global alignment kernels," ICML 2011.
#     190     """  # noqa: E501
# --> 191     unnormalized_matrix = _cdist_generic(dist_fun=unnormalized_gak,
#     192                                          dataset1=dataset1,
#     193                                          dataset2=dataset2,
#     194                                          n_jobs=n_jobs,
#     195                                          verbose=verbose,
#     196                                          sigma=sigma,
#     197                                          compute_diagonal=True)
#     198     dataset1 = to_time_series_dataset(dataset1)
#     199     if dataset2 is None:
#
# File c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\site-packages\tslearn\metrics\utils.py:62, in _cdist_generic(dist_fun, dataset1, dataset2, n_jobs, verbose, compute_diagonal, dtype, *args, **kwargs)
#      58 matrix = numpy.zeros((len(dataset1), len(dataset1)))
#      59 indices = numpy.triu_indices(len(dataset1),
#      60                              k=0 if compute_diagonal else 1,
#      61                              m=len(dataset1))
# ---> 62 matrix[indices] = Parallel(n_jobs=n_jobs,
#      63                            prefer="threads",
#      64                            verbose=verbose)(
#      65     delayed(dist_fun)(
#      66         dataset1[i], dataset1[j],
#      67         *args, **kwargs
#      68     )
#      69     for i in range(len(dataset1))
#      70     for j in range(i if compute_diagonal else i + 1,
#      71                    len(dataset1))
#      72 )
#      73 indices = numpy.tril_indices(len(dataset1), k=-1, m=len(dataset1))
#      74 matrix[indices] = matrix.T[indices]
#
# File c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:1098, in Parallel.__call__(self, iterable)
#    1095     self._iterating = False
#    1097 with self._backend.retrieval_context():
# -> 1098     self.retrieve()
#    1099 # Make sure that we get a last message telling us we are done
#    1100 elapsed_time = time.time() - self._start_time
#
# File c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\site-packages\joblib\parallel.py:975, in Parallel.retrieve(self)
#     973 try:
#     974     if getattr(self._backend, 'supports_timeout', False):
# --> 975         self._output.extend(job.get(timeout=self.timeout))
#     976     else:
#     977         self._output.extend(job.get())
#
# File c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
