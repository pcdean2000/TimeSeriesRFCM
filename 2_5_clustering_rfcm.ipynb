# %%
import os
import warnings
warnings.filterwarnings('ignore')

import numpy as np

from glob import glob
from pathlib import Path
from rfcm import RFCM

INTERVAL = 30

# %%
def dropna(nparray):
    if isinstance(nparray[0], np.ndarray):
        return np.array([dropna(x) for x in nparray])
    else:
        return nparray[~np.isnan(nparray)]

# %%
for direction in ["src", "dst"]:
    for dirname in glob(Path(f'timeseries_feature/interval_{INTERVAL}_{direction}*/*').__str__()):
        print("Dir: ", dirname)
        if os.path.exists(os.path.join(dirname, "rfcm_label.npy")):
            continue
        pyts_dataset = np.load(os.path.join(dirname, "pyts_dataset.npy"))
        pyts_dataset = dropna(pyts_dataset)
        print("\tPyts dataset shape: ", pyts_dataset.shape)
        model = RFCM(n_clusters=10, max_iter=10, random_state=0, n_jobs=4, epsilon=1e-3)
        model.fit(pyts_dataset)
        y_pred = model.labels_
        np.save(os.path.join(dirname, "rfcm_label.npy"), y_pred)
        print("\tRFCM label shape: ", y_pred.shape)
        del pyts_dataset, model, y_pred
# Out:
# Dir:  timeseries_feature\interval_30_src_feature\bytes-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature\bytes-flows
# Dir:  timeseries_feature\interval_30_src_feature\bytes-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature\bytes-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature\bytes-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature\bytes-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature\bytes_packets-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature\bytes_packets-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature\bytes_packets-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature\bytes_packets-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature\flows-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature\flows-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature\flows-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature\flows-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature\flows-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature\flows_(bytes_packets)-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature\flows_(bytes_packets)-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature\flows_(bytes_packets)-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature\nDstIP-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature\nDstIP-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature\nSrcPort-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature\packets-bytes
# Dir:  timeseries_feature\interval_30_src_feature\packets-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature\packets-flows
# Dir:  timeseries_feature\interval_30_src_feature\packets-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature\packets-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature\packets-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature\packets-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\bytes-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\bytes-flows
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\bytes-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\bytes-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\bytes-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\bytes-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\bytes_packets-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\bytes_packets-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\bytes_packets-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\bytes_packets-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\flows-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\flows-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\flows-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\flows-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\flows-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\flows_(bytes_packets)-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\flows_(bytes_packets)-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\flows_(bytes_packets)-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\nDstIP-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\nDstIP-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\nSrcPort-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\packets-bytes
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\packets-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\packets-flows
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\packets-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\packets-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\packets-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_combined\packets-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\bytes-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\bytes-flows
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\bytes-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\bytes-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\bytes-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\bytes-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\bytes_packets-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\bytes_packets-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\bytes_packets-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\bytes_packets-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\flows-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\flows-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\flows-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\flows-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\flows-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\flows_(bytes_packets)-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\flows_(bytes_packets)-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\flows_(bytes_packets)-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\nDstIP-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\nDstIP-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\nSrcPort-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\packets-bytes
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\packets-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\packets-flows
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\packets-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\packets-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\packets-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_detrend\packets-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\bytes-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\bytes-flows
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\bytes-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\bytes-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\bytes-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\bytes-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\bytes_packets-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\bytes_packets-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\bytes_packets-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\bytes_packets-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\flows-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\flows-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\flows-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\flows-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\flows-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\flows_(bytes_packets)-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\flows_(bytes_packets)-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\flows_(bytes_packets)-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\nDstIP-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\nDstIP-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\nSrcPort-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\packets-bytes
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\packets-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\packets-flows
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\packets-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\packets-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\packets-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_seasonal\packets-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\bytes-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\bytes-flows
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\bytes-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\bytes-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\bytes-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\bytes-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\bytes_packets-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\bytes_packets-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\bytes_packets-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\bytes_packets-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\flows-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\flows-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\flows-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\flows-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\flows-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\flows_(bytes_packets)-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\flows_(bytes_packets)-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\flows_(bytes_packets)-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\nDstIP-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\nDstIP-nSrcPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\nSrcPort-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\packets-bytes
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\packets-bytes_packets
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\packets-flows
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\packets-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\packets-nDstIP
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\packets-nDstPort
# Dir:  timeseries_feature\interval_30_src_feature_reconstructed_STL_trend\packets-nSrcPort
# Dir:  timeseries_feature\interval_30_dst_feature\bytes-bytes_packets
# Dir:  timeseries_feature\interval_30_dst_feature\bytes-flows
# Dir:  timeseries_feature\interval_30_dst_feature\bytes-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_dst_feature\bytes-nDstPort
# Dir:  timeseries_feature\interval_30_dst_feature\bytes-nSrcIP
# Dir:  timeseries_feature\interval_30_dst_feature\bytes-nSrcPort
# Dir:  timeseries_feature\interval_30_dst_feature\bytes_packets-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_dst_feature\bytes_packets-nDstPort
# Dir:  timeseries_feature\interval_30_dst_feature\bytes_packets-nSrcIP
# Dir:  timeseries_feature\interval_30_dst_feature\bytes_packets-nSrcPort
# Dir:  timeseries_feature\interval_30_dst_feature\flows-bytes_packets
# Dir:  timeseries_feature\interval_30_dst_feature\flows-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_30_dst_feature\flows-nDstPort
# Dir:  timeseries_feature\interval_30_dst_feature\flows-nSrcIP
# Dir:  timeseries_feature\interval_30_dst_feature\flows-nSrcPort
# Dir:  timeseries_feature\interval_30_dst_feature\flows_(bytes_packets)-nDstPort
# Dir:  timeseries_feature\interval_30_dst_feature\flows_(bytes_packets)-nSrcIP
# Dir:  timeseries_feature\interval_30_dst_feature\flows_(bytes_packets)-nSrcPort
# Dir:  timeseries_feature\interval_30_dst_feature\nSrcIP-nDstPort
# Dir:  timeseries_feature\interval_30_dst_feature\nSrcIP-nSrcPort
# Dir:  timeseries_feature\interval_30_dst_feature\nSrcPort-nDstPort
# Dir:  timeseries_feature\interval_30_dst_feature\packets-bytes
# Dir:  timeseries_feature\interval_30_dst_feature\packets-bytes_packets
# 	Pyts dataset shape:  (190016, 2, 31)
# ----- Start size insensitive rfcm -----
# -> 3.669700785371862 -> 343.15055800336313 -> 2673.334612478248 -> 1210.2499941077817 -> 306.0078563728347 -> 925.0377689531387 -> 782.5505894800613 -> 559.5219959756265 -> 289.86365485041375
# ----- Start noise resistant rfcm -----
# -> 51.34523389875494 -> 4.120517251995238 -> 0.3388016392972989 -> 0.0277597733994899 -> 0.0022718930475337726 -> 0.00018586243770578112 Convergence in 6 iterations, difference is 0.00018586243770578112
#
# 	RFCM label shape:  (190016,)
# Dir:  timeseries_feature\interval_30_dst_feature\packets-flows
# 	Pyts dataset shape:  (190016, 2, 31)
# ----- Start size insensitive rfcm -----
# -> 3.124004029678725 -> 57.39203767644972 -> 154.0650127649938 -> 575.3206312269583 -> 1367.705766372026 -> 2394.9569151620626 -> 3053.8454161579193 -> 3491.305678017066 -> 2990.6623159719065
# ----- Start noise resistant rfcm -----
# -> 13.899202563522463 -> 0.415536643645151 -> 0.01722830545345812 -> 0.0007249398084881788 Convergence in 4 iterations, difference is 0.0007249398084881788
#
# 	RFCM label shape:  (190016,)
# Dir:  timeseries_feature\interval_30_dst_feature\packets-flows_(bytes_packets)
# 	Pyts dataset shape:  (190016, 2, 31)
# ----- Start size insensitive rfcm -----
# -> 1.6884355671084308 -> 63.77962099921998 -> 16.475054251729112 -> 268.612204256997 -> 191.268409537482 -> 865.3691450366316 -> 1290.25465886982 -> 2464.5217024358976 -> 2827.6230163752894
# ----- Start noise resistant rfcm -----
# -> 13.76935951433577 -> 0.3094020304653175 -> 0.013034551407370408 -> 0.0005455439650181934 Convergence in 4 iterations, difference is 0.0005455439650181934
#
# 	RFCM label shape:  (190016,)
# Dir:  timeseries_feature\interval_30_dst_feature\packets-nDstPort
# 	Pyts dataset shape:  (190016, 2, 31)
# ----- Start size insensitive rfcm -----
# -> 3.124004029678725 -> 57.39203767644972 -> 154.0650127649938 -> 575.3206312269583 -> 1367.705766372026 -> 2394.9569151620626 -> 3053.8454161579193 -> 3491.305678017066 -> 2990.6623159719065
# ----- Start noise resistant rfcm -----
# -> 13.899202563522463 -> 0.415536643645151 -> 0.01722830545345812 -> 0.0007249398084881788 Convergence in 4 iterations, difference is 0.0007249398084881788
#
# 	RFCM label shape:  (190016,)
# Dir:  timeseries_feature\interval_30_dst_feature\packets-nSrcIP
# 	Pyts dataset shape:  (190016, 2, 31)
# ----- Start size insensitive rfcm -----
# -> 3.124004029678725 -> 57.39203767644972 -> 154.0650127649938 -> 575.3206312269583 -> 1367.705766372026 -> 2394.9569151620626 -> 3053.8454161579193 -> 3491.305678017066 -> 2990.6623159719065
# ----- Start noise resistant rfcm -----
# -> 13.899202563522463 -> 0.415536643645151 -> 0.01722830545345812 -> 0.0007249398084881788 Convergence in 4 iterations, difference is 0.0007249398084881788
#
# 	RFCM label shape:  (190016,)
# Dir:  timeseries_feature\interval_30_dst_feature\packets-nSrcPort
# 	Pyts dataset shape:  (190016, 2, 31)
# ----- Start size insensitive rfcm -----
# -> 3.124004029678725 -> 57.39203767644972 -> 154.0650127649938 -> 575.3206312269583 -> 1367.705766372026 -> 2394.9569151620626 -> 3053.8454161579193 -> 3491.305678017066 -> 2990.6623159719065
# ----- Start noise resistant rfcm -----
# -> 13.899202563522463 -> 0.415536643645151 -> 0.01722830545345812 -> 0.0007249398084881788 Convergence in 4 iterations, difference is 0.0007249398084881788
#
# 	RFCM label shape:  (190016,)
# Dir:  timeseries_feature\interval_30_dst_feature_reconstructed_STL_combined\bytes-bytes_packets
# 	Pyts dataset shape:  (190016, 2, 31)
# ----- Start size insensitive rfcm -----
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "g:\Github\TimeSeriesRFCM\rfcm.py", line 42, in do_one_calc_dtw
#     cost = dtw(line[index].get_data(), center_node[index].get_data(), dist=distance)
#   File "c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\site-packages\pyts\metrics\dtw.py", line 1007, in dtw
#     _check_input_dtw(x, y, precomputed_cost, dist, method)
#   File "c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\site-packages\pyts\metrics\dtw.py", line 65, in _check_input_dtw
#     x = check_array(x, ensure_2d=False, dtype='float64')
#   File "c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py", line 919, in check_array
#     _assert_all_finite(
#   File "c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py", line 161, in _assert_all_finite
#     raise ValueError(msg_err)
# ValueError: Input contains NaN.
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 9
#       7 print("\tPyts dataset shape: ", pyts_dataset.shape)
#       8 model = RFCM(n_clusters=10, max_iter=10, random_state=0, n_jobs=4, epsilon=1e-3)
# ----> 9 model.fit(pyts_dataset)
#      10 y_pred = model.labels_
#      11 np.save(os.path.join(dirname, "rfcm_label.npy"), y_pred)
#
# File g:\Github\TimeSeriesRFCM\rfcm.py:201, in RFCM.fit(self, data, y, sample_weight)
#     198 if sample_weight is not None:
#     199     sample_weight = skv._check_sample_weight(sample_weight, data)
# --> 201 U, center = self._noise_resistant_rfcm(
#     202     data, self.n_clusters, self.epsilon, self.expo, self.alpha, self.max_iter, self.p)
#     204 self.cluster_centers_ = center
#     205 self._n_cluster_out = self.cluster_centers_.shape[0]
#
# File g:\Github\TimeSeriesRFCM\rfcm.py:141, in RFCM._noise_resistant_rfcm(self, data, n_clusters, epsilon, expo, alpha, max_iter, p)
#     140 def _noise_resistant_rfcm(self, data, n_clusters, epsilon, expo, alpha, max_iter, p):
# --> 141     U, center = self._size_insensitive_rfcm(
#     142         data, n_clusters, epsilon, expo, max_iter, p)
#     144     print("----- Start noise resistant rfcm -----")
#     145     for i in range(max_iter):
#     146         # distance part of the U update equation
#
# File g:\Github\TimeSeriesRFCM\rfcm.py:111, in RFCM._size_insensitive_rfcm(self, data, n_clusters, epsilon, expo, max_iter, p)
#     107 interaction_reduction = np.subtract(
#     108     1, np.take_along_axis(relative_size.T, np.expand_dims(index_array, axis=-1), axis=-1)).T  # The interaction reduction, Rho_j in the paper
#     110 # distance part of the U update equation
# --> 111 dist_part = self.calc_dtw(data, center) ** (-1 / (expo - 1))
#     113 # coefficient part of the U update equation
#     114 coef_part = np.power(
#     115     1 + np.multiply(membership, np.divide(1, np.power(n_data, p + 1))), (-1 / (expo - 1)))
#
# File g:\Github\TimeSeriesRFCM\rfcm.py:60, in RFCM.calc_dtw(self, data, center)
#      50 for center_node in center:
#      51     # dist_center_node = []
#      52     # for line in data:
#    (...)
#      57     #         dist_feature.append(cost)
#      58     #     dist_center_node.append(np.linalg.norm(np.array(dist_feature)))
#      59     with Pool(processes=self.n_jobs) as pool:
# ---> 60         dist_center_node = pool.starmap(self.do_one_calc_dtw, [(line, center_node) for line in data])
#      61     dist.append(dist_center_node)
#      62 return np.array(dist)
#
# File c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File c:\Users\pcdea\AppData\Local\Programs\Python\Python310\lib\multiprocessing\pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# ValueError: Input contains NaN.

# %%
# class EmptyClusterError(Exception):
#     def __init__(self, message=""):
#         super().__init__()
#         self.message = message

#     def __str__(self):
#         if len(self.message) > 0:
#             suffix = " (%s)" % self.message
#         else:
#             suffix = ""
#         return "Cluster assignments lead to at least one empty cluster" + \
#                suffix

# %%
# class TimeSeriesCentroidBasedClusteringMixin:
#     """Mixin class for centroid-based clustering of time series."""
#     def _post_fit(self, X_fitted, centroids, inertia):
#         if np.isfinite(inertia) and (centroids is not None):
#             self.cluster_centers_ = centroids
#             self._assign(X_fitted)
#             self._X_fit = X_fitted
#             self.inertia_ = inertia
#         else:
#             self._X_fit = None

# %%
# def _check_initial_guess(init, n_clusters):
#     if hasattr(init, '__array__'):
#         assert init.shape[0] == n_clusters, \
#             "Initial guess index array must contain {} samples," \
#             " {} given".format(n_clusters, init.shape[0])

# %%
# def _k_init_metric(X, n_clusters, cdist_metric, random_state, n_local_trials=None):
#     n_samples, n_timestamps, n_features = X.shape

#     centers = np.empty((n_clusters, n_timestamps, n_features), dtype=X.dtype)

#     # Set the number of local seeding trials if none is given
#     if n_local_trials is None:
#         # This is what Arthur/Vassilvitskii tried, but did not report
#         # specific results for other than mentioning in the conclusion
#         # that it helped.
#         n_local_trials = 2 + int(np.log(n_clusters))

#     # Pick first center randomly
#     center_id = random_state.randint(n_samples)
#     centers[0] = X[center_id]

#     # Initialize list of closest distances and calculate current potential
#     closest_dist_sq = cdist_metric(centers[0, np.newaxis], X) ** 2
#     current_pot = closest_dist_sq.sum()

#     # Pick the remaining n_clusters-1 points
#     for c in range(1, n_clusters):
#         # Choose center candidates by sampling with probability proportional
#         # to the squared distance to the closest existing center
#         rand_vals = random_state.random_sample(n_local_trials) * current_pot
#         candidate_ids = np.searchsorted(stable_cumsum(closest_dist_sq), rand_vals)
#         # XXX: numerical imprecision can result in a candidate_id out of range
#         np.clip(candidate_ids, None, closest_dist_sq.size - 1, out=candidate_ids)

#         # Compute distances to center candidates
#         distance_to_candidates = cdist_metric(X[candidate_ids], X) ** 2

#         # update closest distances squared and potential for each candidate
#         np.minimum(closest_dist_sq, distance_to_candidates, out=distance_to_candidates)
#         candidates_pot = distance_to_candidates.sum(axis=1)

#         # Decide which candidate is the best
#         best_candidate = np.argmin(candidates_pot)
#         current_pot = candidates_pot[best_candidate]
#         closest_dist_sq = distance_to_candidates[best_candidate]
#         best_candidate = candidate_ids[best_candidate]

#         # Permanently add best center candidate found in local tries
#         centers[c] = X[best_candidate]

#     return centers

# %%
# class TimeSeriesRFCM(TransformerMixin, ClusterMixin, TimeSeriesCentroidBasedClusteringMixin, BaseModelPackage, TimeSeriesBaseEstimator):
#     def __init__(self, n_clusters=3, max_iter=50, tol=1e-6, n_init=1, metric="softdtw", max_iter_barycenter=100, metric_params=None, n_jobs=None, dtw_inertia=False, verbose=0, random_state=None, init='RFCM') -> None:
#         super().__init__()
#         self.n_clusters = n_clusters
#         self.max_iter = max_iter
#         self.tol = tol
#         self.n_init = n_init
#         self.metric = metric
#         self.max_iter_barycenter = max_iter_barycenter
#         self.metric_params = metric_params
#         self.n_jobs = n_jobs
#         self.dtw_inertia = dtw_inertia
#         self.verbose = verbose
#         self.random_state = random_state
#         self.init = init
        
#     def _is_fitted(self):
#         check_is_fitted(self, ["cluster_centers_"])
#         return True
    
#     def _get_metric_params(self):
#         if self.metric_params is None:
#             metric_params = {}
#         else:
#             metric_params = self.metric_params.copy()
#         if "n_jobs" in metric_params:
#             del metric_params["n_jobs"]
#         return metric_params
    
#     def _fit_one_init(self, X, x_squared_norms, rs):
#         metric_params = self._get_metric_params()
#         n_ts, sz, d = X.shape
#         if hasattr(self.init, '__array__'):
#             self.cluster_centers_ = self.init.copy()
#         elif isinstance(self.init, str) and self.init == 'RFCM':
#             if self.metric == "softdtw":
#                 def metric_fun(x, y):
#                     return cdist_soft_dtw(x, y, **metric_params)
#             else:
#                 raise ValueError("Incorrect metric: %s (should be one of 'softdtw')" % self.metric)
#             self.cluster_centers_ = _k_init_metric(X, self.n_clusters, cdist_metric=metric_fun, random_state=rs)
#             for i in range(self.n_clusters):
#                 self.cluster_centers_[i] = X[rs.randint(n_ts)]
        
#     def _transform(self, X):
#         metric_params = self._get_metric_params()
#         if self.metric == "softdtw":
#             return cdist_soft_dtw(X, self.cluster_centers_, **metric_params)
#         else:
#             raise ValueError("Incorrect metric: %s (should be one of 'softdtw')" % self.metric)
        
#     def _update_centroids(self, X):
#         metric_params = self._get_metric_params()
#         for k in 
    
#     def fit(self, X, y=None):
#         X = check_array(X, allow_nd=True, force_all_finite='allow-nan')
        
#         if hasattr(self.init, '__array__'):
#             X = check_dims(X, X_fit_dims=self.init.shape, extend=True, check_n_features_only=(self.metric != "euclidean"))
            
#         self.labels_ = None
#         self.inertia_ = np.inf
#         self.cluster_centers_ = None
#         self._X_fit = None
#         self._squared_inertia = True

#         self.n_iter_ = 0

#         max_attempts = max(self.n_init, 10)

#         X_ = to_time_series_dataset(X)
#         rs = check_random_state(self.random_state)
        
#         x_squared_norms = None
#         _check_initial_guess(self.init, self.n_clusters)
        
#         best_correct_centroids = None
#         min_inertia = np.inf
#         n_successful = 0
#         n_attempts = 0
#         while n_successful < self.n_init and n_attempts < max_attempts:
#             try:
#                 if self.verbose and self.n_init > 1:
#                     print("Init %d" % (n_successful + 1))
#                 n_attempts += 1
#                 self._fit_one_init(X_, x_squared_norms, rs)
#                 if self.inertia_ < min_inertia:
#                     best_correct_centroids = self.cluster_centers_.copy()
#                     min_inertia = self.inertia_
#                     self.n_iter_ = self._iter
#                 n_successful += 1
#             except EmptyClusterError:
#                 if self.verbose:
#                     print("Resumed because of empty cluster")
#         self._post_fit(X_, best_correct_centroids, min_inertia)
#         return
