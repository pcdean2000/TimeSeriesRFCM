# %%
import os
import warnings
warnings.filterwarnings('ignore')

import numpy as np

from glob import glob
from pathlib import Path
from rfcm import RFCM

INTERVAL = 5

# %%
def dropna(nparray):
    if isinstance(nparray[0], np.ndarray):
        return np.array([dropna(x) for x in nparray])
    else:
        return nparray[~np.isnan(nparray)]

# %%
for direction in ["src"]:
    for dirname in glob(Path(f'timeseries_feature/interval_{INTERVAL}_{direction}*/*').__str__()):
        print("Dir: ", dirname)
        if os.path.exists(os.path.join(dirname, "rfcm_label.npy")):
            continue
        pyts_dataset = np.load(os.path.join(dirname, "pyts_dataset.npy"))
        pyts_dataset = dropna(pyts_dataset)
        print("\tPyts dataset shape: ", pyts_dataset.shape)
        model = RFCM(n_clusters=10, max_iter=10, random_state=0, n_jobs=4, epsilon=1e-3)
        model.fit(pyts_dataset)
        y_pred = model.labels_
        np.save(os.path.join(dirname, "rfcm_label.npy"), y_pred)
        print("\tRFCM label shape: ", y_pred.shape)
        del pyts_dataset, model, y_pred
# Out:
# Dir:  timeseries_feature\interval_5_src_feature\bytes-bytes_packets
# Dir:  timeseries_feature\interval_5_src_feature\bytes-flows
# Dir:  timeseries_feature\interval_5_src_feature\bytes-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_5_src_feature\bytes-nDstIP
# Dir:  timeseries_feature\interval_5_src_feature\bytes-nDstPort
# Dir:  timeseries_feature\interval_5_src_feature\bytes-nSrcPort
# Dir:  timeseries_feature\interval_5_src_feature\bytes_packets-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_5_src_feature\bytes_packets-nDstIP
# Dir:  timeseries_feature\interval_5_src_feature\bytes_packets-nDstPort
# Dir:  timeseries_feature\interval_5_src_feature\bytes_packets-nSrcPort
# Dir:  timeseries_feature\interval_5_src_feature\flows-bytes_packets
# Dir:  timeseries_feature\interval_5_src_feature\flows-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_5_src_feature\flows-nDstIP
# Dir:  timeseries_feature\interval_5_src_feature\flows-nDstPort
# Dir:  timeseries_feature\interval_5_src_feature\flows-nSrcPort
# Dir:  timeseries_feature\interval_5_src_feature\flows_(bytes_packets)-nDstIP
# Dir:  timeseries_feature\interval_5_src_feature\flows_(bytes_packets)-nDstPort
# Dir:  timeseries_feature\interval_5_src_feature\flows_(bytes_packets)-nSrcPort
# Dir:  timeseries_feature\interval_5_src_feature\nDstIP-nDstPort
# Dir:  timeseries_feature\interval_5_src_feature\nDstIP-nSrcPort
# Dir:  timeseries_feature\interval_5_src_feature\nSrcPort-nDstPort
# Dir:  timeseries_feature\interval_5_src_feature\packets-bytes
# Dir:  timeseries_feature\interval_5_src_feature\packets-bytes_packets
# Dir:  timeseries_feature\interval_5_src_feature\packets-flows
# Dir:  timeseries_feature\interval_5_src_feature\packets-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_5_src_feature\packets-nDstIP
# Dir:  timeseries_feature\interval_5_src_feature\packets-nDstPort
# Dir:  timeseries_feature\interval_5_src_feature\packets-nSrcPort
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\bytes-bytes_packets
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\bytes-flows
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\bytes-flows_(bytes_packets)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\bytes-nDstIP
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\bytes-nDstPort
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\bytes-nSrcPort
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\bytes_packets-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8793387953960425 -> 41.68970566002797 -> 446.53565716299016 -> 130.14883078751154 -> 520.5337250981742 -> 780.0135620037055 -> 1058.5684207852255 -> 908.9045524347896 -> 624.622581133216
# ----- Start noise resistant rfcm -----
# -> 17.212708814352773 -> 0.15031296831934998 -> 0.0013432556630956587 -> 1.2060727416056878e-05 Convergence in 4 iterations, difference is 1.2060727416056878e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\bytes_packets-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804263 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134145 -> 1197.0038282330556 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.752214128426893 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\bytes_packets-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804263 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134145 -> 1197.0038282330556 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.752214128426893 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\bytes_packets-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804263 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134145 -> 1197.0038282330556 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.752214128426893 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\flows-bytes_packets
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804264 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134144 -> 1197.0038282330554 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.75221412842689 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\flows-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019722 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.46581471618384 -> 47.758860373549815 -> 567.5824887811616 -> 101.19855389100728
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\flows-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\flows-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\flows-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\flows_(bytes_packets)-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019721 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.4658147161838 -> 47.75886037354981 -> 567.5824887811616 -> 101.1985538910073
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\flows_(bytes_packets)-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019721 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.4658147161838 -> 47.75886037354981 -> 567.5824887811616 -> 101.1985538910073
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\flows_(bytes_packets)-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019721 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.4658147161838 -> 47.75886037354981 -> 567.5824887811616 -> 101.1985538910073
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\nDstIP-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\nDstIP-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\nSrcPort-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\packets-bytes
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3680918894357 -> 88702.91651275569 -> 18185.766491642975 -> 906624.5418614764 -> 61695.73900383436 -> 3272542.3517634124 -> 980794.8534485417 -> 1637791.0806429174 -> 8478848.672533061
# ----- Start noise resistant rfcm -----
# -> 2297.383712252874 -> 6.7574135602170395 -> 0.017883138140510454 -> 4.595253350251163e-05 Convergence in 4 iterations, difference is 4.595253350251163e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\packets-bytes_packets
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.9808492478520816 -> 44.19719059290545 -> 448.41673596723075 -> 134.25640019111495 -> 466.5712186997703 -> 889.8893103190377 -> 882.1173959448618 -> 1066.0925186215813 -> 1486.799966174544
# ----- Start noise resistant rfcm -----
# -> 13.731293452275004 -> 0.11344772790920994 -> 0.000873690277643182 Convergence in 3 iterations, difference is 0.000873690277643182
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\packets-flows
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\packets-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.8678831515991224 -> 31.527243444431647 -> 17.178019574817835 -> 200.96766572612682 -> 94.76798078434318 -> 961.9441804400229 -> 213.78078934560335 -> 1229.5984369750195 -> 4058.4498042838172
# ----- Start noise resistant rfcm -----
# -> 2.8710579652306434 -> 0.013262472057687207 -> 5.919961959479259e-05 Convergence in 3 iterations, difference is 5.919961959479259e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\packets-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\packets-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_combined\packets-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\bytes-bytes_packets
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 805.0952408955869 -> 88782.0731609687 -> 17695.830881478374 -> 922580.2192479096 -> 47647.7905531314 -> 3272454.449551739 -> 980861.108759402 -> 1637792.038749199 -> 8478847.755810952
# ----- Start noise resistant rfcm -----
# -> 2297.9479597386758 -> 6.77597400944019 -> 0.016970367833044866 -> 4.001633530706078e-05 Convergence in 4 iterations, difference is 4.001633530706078e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\bytes-flows
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3673121539812 -> 88702.85289622174 -> 18185.74640796412 -> 906624.0979821872 -> 61695.731516320055 -> 3272541.652978686 -> 980794.6287652353 -> 1637790.8704289047 -> 8478846.88115775
# ----- Start noise resistant rfcm -----
# -> 2297.381762163684 -> 6.7573090947367485 -> 0.017882483613986873 -> 4.595075122434994e-05 Convergence in 4 iterations, difference is 4.595075122434994e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\bytes-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3697375082565 -> 88702.81742942907 -> 18185.787777414804 -> 906623.9803834786 -> 61695.727286797395 -> 3272541.5193888242 -> 980794.5858068259 -> 1637790.8454350522 -> 8478846.607870577
# ----- Start noise resistant rfcm -----
# -> 2297.379481103788 -> 6.757379761919584 -> 0.017882468376205718 -> 4.595098330653805e-05 Convergence in 4 iterations, difference is 4.595098330653805e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\bytes-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3673121539812 -> 88702.85289622174 -> 18185.74640796412 -> 906624.0979821872 -> 61695.731516320055 -> 3272541.652978686 -> 980794.6287652353 -> 1637790.8704289047 -> 8478846.88115775
# ----- Start noise resistant rfcm -----
# -> 2297.381762163684 -> 6.7573090947367485 -> 0.017882483613986873 -> 4.595075122434994e-05 Convergence in 4 iterations, difference is 4.595075122434994e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\bytes-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3673121539812 -> 88702.85289622174 -> 18185.74640796412 -> 906624.0979821872 -> 61695.731516320055 -> 3272541.652978686 -> 980794.6287652353 -> 1637790.8704289047 -> 8478846.88115775
# ----- Start noise resistant rfcm -----
# -> 2297.381762163684 -> 6.7573090947367485 -> 0.017882483613986873 -> 4.595075122434994e-05 Convergence in 4 iterations, difference is 4.595075122434994e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\bytes-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3673121539812 -> 88702.85289622174 -> 18185.74640796412 -> 906624.0979821872 -> 61695.731516320055 -> 3272541.652978686 -> 980794.6287652353 -> 1637790.8704289047 -> 8478846.88115775
# ----- Start noise resistant rfcm -----
# -> 2297.381762163684 -> 6.7573090947367485 -> 0.017882483613986873 -> 4.595075122434994e-05 Convergence in 4 iterations, difference is 4.595075122434994e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\bytes_packets-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8793387953960425 -> 41.68970566002797 -> 446.53565716299016 -> 130.14883078751154 -> 520.5337250981742 -> 780.0135620037055 -> 1058.5684207852255 -> 908.9045524347896 -> 624.622581133216
# ----- Start noise resistant rfcm -----
# -> 17.212708814352773 -> 0.15031296831934998 -> 0.0013432556630956587 -> 1.2060727416056878e-05 Convergence in 4 iterations, difference is 1.2060727416056878e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\bytes_packets-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804263 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134145 -> 1197.0038282330556 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.752214128426893 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\bytes_packets-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804263 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134145 -> 1197.0038282330556 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.752214128426893 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\bytes_packets-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804263 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134145 -> 1197.0038282330556 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.752214128426893 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\flows-bytes_packets
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804264 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134144 -> 1197.0038282330554 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.75221412842689 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\flows-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019722 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.46581471618384 -> 47.758860373549815 -> 567.5824887811616 -> 101.19855389100728
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\flows-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\flows-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\flows-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\flows_(bytes_packets)-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019721 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.4658147161838 -> 47.75886037354981 -> 567.5824887811616 -> 101.1985538910073
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\flows_(bytes_packets)-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019721 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.4658147161838 -> 47.75886037354981 -> 567.5824887811616 -> 101.1985538910073
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\flows_(bytes_packets)-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019721 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.4658147161838 -> 47.75886037354981 -> 567.5824887811616 -> 101.1985538910073
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\nDstIP-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\nDstIP-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\nSrcPort-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\packets-bytes
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3680918894357 -> 88702.91651275569 -> 18185.766491642975 -> 906624.5418614764 -> 61695.73900383436 -> 3272542.3517634124 -> 980794.8534485417 -> 1637791.0806429174 -> 8478848.672533061
# ----- Start noise resistant rfcm -----
# -> 2297.383712252874 -> 6.7574135602170395 -> 0.017883138140510454 -> 4.595253350251163e-05 Convergence in 4 iterations, difference is 4.595253350251163e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\packets-bytes_packets
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.9808492478520816 -> 44.19719059290545 -> 448.41673596723075 -> 134.25640019111495 -> 466.5712186997703 -> 889.8893103190377 -> 882.1173959448618 -> 1066.0925186215813 -> 1486.799966174544
# ----- Start noise resistant rfcm -----
# -> 13.731293452275004 -> 0.11344772790920994 -> 0.000873690277643182 Convergence in 3 iterations, difference is 0.000873690277643182
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\packets-flows
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\packets-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.8678831515991224 -> 31.527243444431647 -> 17.178019574817835 -> 200.96766572612682 -> 94.76798078434318 -> 961.9441804400229 -> 213.78078934560335 -> 1229.5984369750195 -> 4058.4498042838172
# ----- Start noise resistant rfcm -----
# -> 2.8710579652306434 -> 0.013262472057687207 -> 5.919961959479259e-05 Convergence in 3 iterations, difference is 5.919961959479259e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\packets-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\packets-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_detrend\packets-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\bytes-bytes_packets
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 805.0952408955869 -> 88782.0731609687 -> 17695.830881478374 -> 922580.2192479096 -> 47647.7905531314 -> 3272454.449551739 -> 980861.108759402 -> 1637792.038749199 -> 8478847.755810952
# ----- Start noise resistant rfcm -----
# -> 2297.9479597386758 -> 6.77597400944019 -> 0.016970367833044866 -> 4.001633530706078e-05 Convergence in 4 iterations, difference is 4.001633530706078e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\bytes-flows
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3673121539812 -> 88702.85289622174 -> 18185.74640796412 -> 906624.0979821872 -> 61695.731516320055 -> 3272541.652978686 -> 980794.6287652353 -> 1637790.8704289047 -> 8478846.88115775
# ----- Start noise resistant rfcm -----
# -> 2297.381762163684 -> 6.7573090947367485 -> 0.017882483613986873 -> 4.595075122434994e-05 Convergence in 4 iterations, difference is 4.595075122434994e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\bytes-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3697375082565 -> 88702.81742942907 -> 18185.787777414804 -> 906623.9803834786 -> 61695.727286797395 -> 3272541.5193888242 -> 980794.5858068259 -> 1637790.8454350522 -> 8478846.607870577
# ----- Start noise resistant rfcm -----
# -> 2297.379481103788 -> 6.757379761919584 -> 0.017882468376205718 -> 4.595098330653805e-05 Convergence in 4 iterations, difference is 4.595098330653805e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\bytes-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3673121539812 -> 88702.85289622174 -> 18185.74640796412 -> 906624.0979821872 -> 61695.731516320055 -> 3272541.652978686 -> 980794.6287652353 -> 1637790.8704289047 -> 8478846.88115775
# ----- Start noise resistant rfcm -----
# -> 2297.381762163684 -> 6.7573090947367485 -> 0.017882483613986873 -> 4.595075122434994e-05 Convergence in 4 iterations, difference is 4.595075122434994e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\bytes-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3673121539812 -> 88702.85289622174 -> 18185.74640796412 -> 906624.0979821872 -> 61695.731516320055 -> 3272541.652978686 -> 980794.6287652353 -> 1637790.8704289047 -> 8478846.88115775
# ----- Start noise resistant rfcm -----
# -> 2297.381762163684 -> 6.7573090947367485 -> 0.017882483613986873 -> 4.595075122434994e-05 Convergence in 4 iterations, difference is 4.595075122434994e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\bytes-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3673121539812 -> 88702.85289622174 -> 18185.74640796412 -> 906624.0979821872 -> 61695.731516320055 -> 3272541.652978686 -> 980794.6287652353 -> 1637790.8704289047 -> 8478846.88115775
# ----- Start noise resistant rfcm -----
# -> 2297.381762163684 -> 6.7573090947367485 -> 0.017882483613986873 -> 4.595075122434994e-05 Convergence in 4 iterations, difference is 4.595075122434994e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\bytes_packets-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8793387953960425 -> 41.68970566002797 -> 446.53565716299016 -> 130.14883078751154 -> 520.5337250981742 -> 780.0135620037055 -> 1058.5684207852255 -> 908.9045524347896 -> 624.622581133216
# ----- Start noise resistant rfcm -----
# -> 17.212708814352773 -> 0.15031296831934998 -> 0.0013432556630956587 -> 1.2060727416056878e-05 Convergence in 4 iterations, difference is 1.2060727416056878e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\bytes_packets-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804263 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134145 -> 1197.0038282330556 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.752214128426893 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\bytes_packets-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804263 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134145 -> 1197.0038282330556 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.752214128426893 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\bytes_packets-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804263 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134145 -> 1197.0038282330556 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.752214128426893 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\flows-bytes_packets
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804264 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134144 -> 1197.0038282330554 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.75221412842689 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\flows-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019722 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.46581471618384 -> 47.758860373549815 -> 567.5824887811616 -> 101.19855389100728
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\flows-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\flows-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\flows-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\flows_(bytes_packets)-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019721 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.4658147161838 -> 47.75886037354981 -> 567.5824887811616 -> 101.1985538910073
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\flows_(bytes_packets)-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019721 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.4658147161838 -> 47.75886037354981 -> 567.5824887811616 -> 101.1985538910073
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\flows_(bytes_packets)-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019721 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.4658147161838 -> 47.75886037354981 -> 567.5824887811616 -> 101.1985538910073
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\nDstIP-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\nDstIP-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\nSrcPort-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\packets-bytes
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3680918894357 -> 88702.91651275569 -> 18185.766491642975 -> 906624.5418614764 -> 61695.73900383436 -> 3272542.3517634124 -> 980794.8534485417 -> 1637791.0806429174 -> 8478848.672533061
# ----- Start noise resistant rfcm -----
# -> 2297.383712252874 -> 6.7574135602170395 -> 0.017883138140510454 -> 4.595253350251163e-05 Convergence in 4 iterations, difference is 4.595253350251163e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\packets-bytes_packets
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.9808492478520816 -> 44.19719059290545 -> 448.41673596723075 -> 134.25640019111495 -> 466.5712186997703 -> 889.8893103190377 -> 882.1173959448618 -> 1066.0925186215813 -> 1486.799966174544
# ----- Start noise resistant rfcm -----
# -> 13.731293452275004 -> 0.11344772790920994 -> 0.000873690277643182 Convergence in 3 iterations, difference is 0.000873690277643182
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\packets-flows
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\packets-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.8678831515991224 -> 31.527243444431647 -> 17.178019574817835 -> 200.96766572612682 -> 94.76798078434318 -> 961.9441804400229 -> 213.78078934560335 -> 1229.5984369750195 -> 4058.4498042838172
# ----- Start noise resistant rfcm -----
# -> 2.8710579652306434 -> 0.013262472057687207 -> 5.919961959479259e-05 Convergence in 3 iterations, difference is 5.919961959479259e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\packets-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\packets-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_seasonal\packets-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\bytes-bytes_packets
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 805.0952408955869 -> 88782.0731609687 -> 17695.830881478374 -> 922580.2192479096 -> 47647.7905531314 -> 3272454.449551739 -> 980861.108759402 -> 1637792.038749199 -> 8478847.755810952
# ----- Start noise resistant rfcm -----
# -> 2297.9479597386758 -> 6.77597400944019 -> 0.016970367833044866 -> 4.001633530706078e-05 Convergence in 4 iterations, difference is 4.001633530706078e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\bytes-flows
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3673121539812 -> 88702.85289622174 -> 18185.74640796412 -> 906624.0979821872 -> 61695.731516320055 -> 3272541.652978686 -> 980794.6287652353 -> 1637790.8704289047 -> 8478846.88115775
# ----- Start noise resistant rfcm -----
# -> 2297.381762163684 -> 6.7573090947367485 -> 0.017882483613986873 -> 4.595075122434994e-05 Convergence in 4 iterations, difference is 4.595075122434994e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\bytes-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3697375082565 -> 88702.81742942907 -> 18185.787777414804 -> 906623.9803834786 -> 61695.727286797395 -> 3272541.5193888242 -> 980794.5858068259 -> 1637790.8454350522 -> 8478846.607870577
# ----- Start noise resistant rfcm -----
# -> 2297.379481103788 -> 6.757379761919584 -> 0.017882468376205718 -> 4.595098330653805e-05 Convergence in 4 iterations, difference is 4.595098330653805e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\bytes-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3673121539812 -> 88702.85289622174 -> 18185.74640796412 -> 906624.0979821872 -> 61695.731516320055 -> 3272541.652978686 -> 980794.6287652353 -> 1637790.8704289047 -> 8478846.88115775
# ----- Start noise resistant rfcm -----
# -> 2297.381762163684 -> 6.7573090947367485 -> 0.017882483613986873 -> 4.595075122434994e-05 Convergence in 4 iterations, difference is 4.595075122434994e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\bytes-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3673121539812 -> 88702.85289622174 -> 18185.74640796412 -> 906624.0979821872 -> 61695.731516320055 -> 3272541.652978686 -> 980794.6287652353 -> 1637790.8704289047 -> 8478846.88115775
# ----- Start noise resistant rfcm -----
# -> 2297.381762163684 -> 6.7573090947367485 -> 0.017882483613986873 -> 4.595075122434994e-05 Convergence in 4 iterations, difference is 4.595075122434994e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\bytes-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3673121539812 -> 88702.85289622174 -> 18185.74640796412 -> 906624.0979821872 -> 61695.731516320055 -> 3272541.652978686 -> 980794.6287652353 -> 1637790.8704289047 -> 8478846.88115775
# ----- Start noise resistant rfcm -----
# -> 2297.381762163684 -> 6.7573090947367485 -> 0.017882483613986873 -> 4.595075122434994e-05 Convergence in 4 iterations, difference is 4.595075122434994e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\bytes_packets-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8793387953960425 -> 41.68970566002797 -> 446.53565716299016 -> 130.14883078751154 -> 520.5337250981742 -> 780.0135620037055 -> 1058.5684207852255 -> 908.9045524347896 -> 624.622581133216
# ----- Start noise resistant rfcm -----
# -> 17.212708814352773 -> 0.15031296831934998 -> 0.0013432556630956587 -> 1.2060727416056878e-05 Convergence in 4 iterations, difference is 1.2060727416056878e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\bytes_packets-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804263 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134145 -> 1197.0038282330556 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.752214128426893 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\bytes_packets-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804263 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134145 -> 1197.0038282330556 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.752214128426893 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\bytes_packets-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804263 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134145 -> 1197.0038282330556 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.752214128426893 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\flows-bytes_packets
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.8999400632433496 -> 43.05746336262359 -> 445.0296244804264 -> 132.5433174901654 -> 447.53869292067543 -> 898.775466516971 -> 825.1422172134144 -> 1197.0038282330554 -> 1206.215174811339
# ----- Start noise resistant rfcm -----
# -> 14.75221412842689 -> 0.12212471172679076 -> 0.0009519351071331665 Convergence in 3 iterations, difference is 0.0009519351071331665
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\flows-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019722 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.46581471618384 -> 47.758860373549815 -> 567.5824887811616 -> 101.19855389100728
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\flows-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\flows-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\flows-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\flows_(bytes_packets)-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019721 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.4658147161838 -> 47.75886037354981 -> 567.5824887811616 -> 101.1985538910073
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\flows_(bytes_packets)-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019721 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.4658147161838 -> 47.75886037354981 -> 567.5824887811616 -> 101.1985538910073
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\flows_(bytes_packets)-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.3930496043019721 -> 27.1932894352843 -> 7.817500767881106 -> 67.86183023210701 -> 42.90338240813689 -> 260.4658147161838 -> 47.75886037354981 -> 567.5824887811616 -> 101.1985538910073
# ----- Start noise resistant rfcm -----
# -> 1.2820763210151158 -> 0.006078614567661133 -> 2.842808706640907e-05 Convergence in 3 iterations, difference is 2.842808706640907e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\nDstIP-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\nDstIP-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\nSrcPort-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.5557428843830503 -> 38.45576981341271 -> 11.05441795120453 -> 95.96713219777811 -> 60.6719800928778 -> 368.34221872188084 -> 67.53793024044707 -> 802.6629873769748 -> 143.09581968032165
# ----- Start noise resistant rfcm -----
# -> 1.8130257745647562 -> 0.00857607652449609 -> 3.994252983629146e-05 Convergence in 3 iterations, difference is 3.994252983629146e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\packets-bytes
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 810.3680918894357 -> 88702.91651275569 -> 18185.766491642975 -> 906624.5418614764 -> 61695.73900383436 -> 3272542.3517634124 -> 980794.8534485417 -> 1637791.0806429174 -> 8478848.672533061
# ----- Start noise resistant rfcm -----
# -> 2297.383712252874 -> 6.7574135602170395 -> 0.017883138140510454 -> 4.595253350251163e-05 Convergence in 4 iterations, difference is 4.595253350251163e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\packets-bytes_packets
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 3.9808492478520816 -> 44.19719059290545 -> 448.41673596723075 -> 134.25640019111495 -> 466.5712186997703 -> 889.8893103190377 -> 882.1173959448618 -> 1066.0925186215813 -> 1486.799966174544
# ----- Start noise resistant rfcm -----
# -> 13.731293452275004 -> 0.11344772790920994 -> 0.000873690277643182 Convergence in 3 iterations, difference is 0.000873690277643182
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\packets-flows
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\packets-flows_(bytes_packets)
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.8678831515991224 -> 31.527243444431647 -> 17.178019574817835 -> 200.96766572612682 -> 94.76798078434318 -> 961.9441804400229 -> 213.78078934560335 -> 1229.5984369750195 -> 4058.4498042838172
# ----- Start noise resistant rfcm -----
# -> 2.8710579652306434 -> 0.013262472057687207 -> 5.919961959479259e-05 Convergence in 3 iterations, difference is 5.919961959479259e-05
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\packets-nDstIP
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\packets-nDstPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)
# Dir:  timeseries_feature\interval_5_src_feature_reconstructed_STL_trend\packets-nSrcPort
# 	Pyts dataset shape:  (101016, 2, 181)
# ----- Start size insensitive rfcm -----
# -> 0.9333538348867906 -> 61.04096412505062 -> 5.030166381465928 -> 251.35731593643905 -> 35.42668510240607 -> 301.14823949242754 -> 24.850488432995835 -> 226.85293543842158 -> 87.01081092908717
# ----- Start noise resistant rfcm -----
# -> 0.5102168093988129 -> 0.0021500814781987045 -> 9.037526564798161e-06 Convergence in 3 iterations, difference is 9.037526564798161e-06
#
# 	RFCM label shape:  (101016,)

# %%
# class EmptyClusterError(Exception):
#     def __init__(self, message=""):
#         super().__init__()
#         self.message = message

#     def __str__(self):
#         if len(self.message) > 0:
#             suffix = " (%s)" % self.message
#         else:
#             suffix = ""
#         return "Cluster assignments lead to at least one empty cluster" + \
#                suffix

# %%
# class TimeSeriesCentroidBasedClusteringMixin:
#     """Mixin class for centroid-based clustering of time series."""
#     def _post_fit(self, X_fitted, centroids, inertia):
#         if np.isfinite(inertia) and (centroids is not None):
#             self.cluster_centers_ = centroids
#             self._assign(X_fitted)
#             self._X_fit = X_fitted
#             self.inertia_ = inertia
#         else:
#             self._X_fit = None

# %%
# def _check_initial_guess(init, n_clusters):
#     if hasattr(init, '__array__'):
#         assert init.shape[0] == n_clusters, \
#             "Initial guess index array must contain {} samples," \
#             " {} given".format(n_clusters, init.shape[0])

# %%
# def _k_init_metric(X, n_clusters, cdist_metric, random_state, n_local_trials=None):
#     n_samples, n_timestamps, n_features = X.shape

#     centers = np.empty((n_clusters, n_timestamps, n_features), dtype=X.dtype)

#     # Set the number of local seeding trials if none is given
#     if n_local_trials is None:
#         # This is what Arthur/Vassilvitskii tried, but did not report
#         # specific results for other than mentioning in the conclusion
#         # that it helped.
#         n_local_trials = 2 + int(np.log(n_clusters))

#     # Pick first center randomly
#     center_id = random_state.randint(n_samples)
#     centers[0] = X[center_id]

#     # Initialize list of closest distances and calculate current potential
#     closest_dist_sq = cdist_metric(centers[0, np.newaxis], X) ** 2
#     current_pot = closest_dist_sq.sum()

#     # Pick the remaining n_clusters-1 points
#     for c in range(1, n_clusters):
#         # Choose center candidates by sampling with probability proportional
#         # to the squared distance to the closest existing center
#         rand_vals = random_state.random_sample(n_local_trials) * current_pot
#         candidate_ids = np.searchsorted(stable_cumsum(closest_dist_sq), rand_vals)
#         # XXX: numerical imprecision can result in a candidate_id out of range
#         np.clip(candidate_ids, None, closest_dist_sq.size - 1, out=candidate_ids)

#         # Compute distances to center candidates
#         distance_to_candidates = cdist_metric(X[candidate_ids], X) ** 2

#         # update closest distances squared and potential for each candidate
#         np.minimum(closest_dist_sq, distance_to_candidates, out=distance_to_candidates)
#         candidates_pot = distance_to_candidates.sum(axis=1)

#         # Decide which candidate is the best
#         best_candidate = np.argmin(candidates_pot)
#         current_pot = candidates_pot[best_candidate]
#         closest_dist_sq = distance_to_candidates[best_candidate]
#         best_candidate = candidate_ids[best_candidate]

#         # Permanently add best center candidate found in local tries
#         centers[c] = X[best_candidate]

#     return centers

# %%
# class TimeSeriesRFCM(TransformerMixin, ClusterMixin, TimeSeriesCentroidBasedClusteringMixin, BaseModelPackage, TimeSeriesBaseEstimator):
#     def __init__(self, n_clusters=3, max_iter=50, tol=1e-6, n_init=1, metric="softdtw", max_iter_barycenter=100, metric_params=None, n_jobs=None, dtw_inertia=False, verbose=0, random_state=None, init='RFCM') -> None:
#         super().__init__()
#         self.n_clusters = n_clusters
#         self.max_iter = max_iter
#         self.tol = tol
#         self.n_init = n_init
#         self.metric = metric
#         self.max_iter_barycenter = max_iter_barycenter
#         self.metric_params = metric_params
#         self.n_jobs = n_jobs
#         self.dtw_inertia = dtw_inertia
#         self.verbose = verbose
#         self.random_state = random_state
#         self.init = init
        
#     def _is_fitted(self):
#         check_is_fitted(self, ["cluster_centers_"])
#         return True
    
#     def _get_metric_params(self):
#         if self.metric_params is None:
#             metric_params = {}
#         else:
#             metric_params = self.metric_params.copy()
#         if "n_jobs" in metric_params:
#             del metric_params["n_jobs"]
#         return metric_params
    
#     def _fit_one_init(self, X, x_squared_norms, rs):
#         metric_params = self._get_metric_params()
#         n_ts, sz, d = X.shape
#         if hasattr(self.init, '__array__'):
#             self.cluster_centers_ = self.init.copy()
#         elif isinstance(self.init, str) and self.init == 'RFCM':
#             if self.metric == "softdtw":
#                 def metric_fun(x, y):
#                     return cdist_soft_dtw(x, y, **metric_params)
#             else:
#                 raise ValueError("Incorrect metric: %s (should be one of 'softdtw')" % self.metric)
#             self.cluster_centers_ = _k_init_metric(X, self.n_clusters, cdist_metric=metric_fun, random_state=rs)
#             for i in range(self.n_clusters):
#                 self.cluster_centers_[i] = X[rs.randint(n_ts)]
        
#     def _transform(self, X):
#         metric_params = self._get_metric_params()
#         if self.metric == "softdtw":
#             return cdist_soft_dtw(X, self.cluster_centers_, **metric_params)
#         else:
#             raise ValueError("Incorrect metric: %s (should be one of 'softdtw')" % self.metric)
        
#     def _update_centroids(self, X):
#         metric_params = self._get_metric_params()
#         for k in 
    
#     def fit(self, X, y=None):
#         X = check_array(X, allow_nd=True, force_all_finite='allow-nan')
        
#         if hasattr(self.init, '__array__'):
#             X = check_dims(X, X_fit_dims=self.init.shape, extend=True, check_n_features_only=(self.metric != "euclidean"))
            
#         self.labels_ = None
#         self.inertia_ = np.inf
#         self.cluster_centers_ = None
#         self._X_fit = None
#         self._squared_inertia = True

#         self.n_iter_ = 0

#         max_attempts = max(self.n_init, 10)

#         X_ = to_time_series_dataset(X)
#         rs = check_random_state(self.random_state)
        
#         x_squared_norms = None
#         _check_initial_guess(self.init, self.n_clusters)
        
#         best_correct_centroids = None
#         min_inertia = np.inf
#         n_successful = 0
#         n_attempts = 0
#         while n_successful < self.n_init and n_attempts < max_attempts:
#             try:
#                 if self.verbose and self.n_init > 1:
#                     print("Init %d" % (n_successful + 1))
#                 n_attempts += 1
#                 self._fit_one_init(X_, x_squared_norms, rs)
#                 if self.inertia_ < min_inertia:
#                     best_correct_centroids = self.cluster_centers_.copy()
#                     min_inertia = self.inertia_
#                     self.n_iter_ = self._iter
#                 n_successful += 1
#             except EmptyClusterError:
#                 if self.verbose:
#                     print("Resumed because of empty cluster")
#         self._post_fit(X_, best_correct_centroids, min_inertia)
#         return
