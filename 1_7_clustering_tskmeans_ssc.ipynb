# %%
import warnings
warnings.filterwarnings('ignore')

import os

import numpy as np

from glob import glob
from pathlib import Path
from tslearn.utils import from_pyts_dataset
from tslearn.clustering import TimeSeriesKMeans

INTERVAL = 30

# %%
for filename in glob(f'interval{INTERVAL}_reconstructed_STL_trend_ts_feature/200702111400/*/*.npy'):
    print(filename)
    
    labelFilename = filename.replace(f'interval{INTERVAL}_reconstructed_STL_trend_ts_feature', f'interval{INTERVAL}_reconstructed_STL_trend_ts_feature_clustered')
    pickleFilename = labelFilename.replace('.npy', '.pkl')
    if os.path.isfile(pickleFilename):
        print('Already done')
        continue
    
    X = np.load(filename)
    X = from_pyts_dataset(X)
    print(X.shape)
    model = TimeSeriesKMeans(n_clusters=10, metric="softdtw", max_iter=10, random_state=0, metric_params={"gamma": .01}, verbose=True)
    model.fit(X)
    print(np.asarray(np.unique(model.labels_, return_counts=True)).T)
    
    os.makedirs(os.path.dirname(labelFilename), exist_ok=True)
    os.makedirs(os.path.dirname(pickleFilename), exist_ok=True)
    
    np.save(labelFilename, model.labels_)
    model.to_pickle(pickleFilename)
# Out:
# interval30_reconstructed_STL_trend_ts_feature/200702111400\bytes-bytes_flows\pyts_dataset.npy
# (102925, 31, 2)
# 666513275477069987315712.000 --> 663921203829769284616192.000 --> 513938631765309278650368.000 --> 291545869591656750120960.000 --> 193965903496919214194688.000 --> 193976707703375786934272.000 --> 149684059379933812621312.000 --> 149695723196069430951936.000 --> 149698594751016733769728.000 --> 149710795652238281801728.000 -->
# [[     0 102855]
#  [     1      1]
#  [     2      1]
#  [     3      1]
#  [     4      2]
#  [     5      7]
#  [     6     54]
#  [     7      1]
#  [     8      1]
#  [     9      2]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\bytes-bytes_packets\pyts_dataset.npy
# (102925, 31, 2)
# 394677582995414153428992.000 --> 394267260796981695479808.000 --> 109388999253790535188480.000 --> 109363704269896436154368.000 --> 98072047774116402429952.000 --> 98072760414117983944704.000 --> 98073445420529243652096.000 --> 98074448846077007233024.000 --> 98070274380485850300416.000 --> 100904800756729584287744.000 -->
# [[     0 102856]
#  [     1      1]
#  [     2      1]
#  [     3      1]
#  [     4      2]
#  [     5      4]
#  [     6     55]
#  [     7      1]
#  [     8      1]
#  [     9      3]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\bytes-flows\pyts_dataset.npy
# (102925, 31, 2)
# 394680452199063171891200.000 --> 245664995679501876723712.000 --> 245135955999254284075008.000 --> 110223669848201035251712.000 --> 98805990661266983616512.000 --> 65666321157399911596032.000 --> 65750823887641977552896.000 --> 65748537240401513283584.000 --> 69837487700372277428224.000 --> 69836911325663192940544.000 -->
# [[     0 102852]
#  [     1      1]
#  [     2      1]
#  [     3      1]
#  [     4      2]
#  [     5      4]
#  [     6     59]
#  [     7      1]
#  [     8      1]
#  [     9      3]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\bytes-flows_(bytes_packets)\pyts_dataset.npy
# (102925, 31, 2)
# 394677217425939993985024.000 --> 394232465758035329941504.000 --> 394185542496581069045760.000 --> 392304791970372479090688.000 --> 114571338354787931389952.000 --> 103266757022255694217216.000 --> 103383033549708408651776.000 --> 106395873678477922140160.000 --> 75253294130469099536384.000 --> 75250101836481633976320.000 -->
# [[     0 102855]
#  [     1      1]
#  [     2      1]
#  [     3      1]
#  [     4      2]
#  [     5      4]
#  [     6     56]
#  [     7      1]
#  [     8      1]
#  [     9      3]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\bytes-nodes\pyts_dataset.npy
# (102925, 31, 2)
# 394680452199063171891200.000 --> 245664995679501876723712.000 --> 245135955999254284075008.000 --> 110223669848201035251712.000 --> 98805990661266983616512.000 --> 65666321157399911596032.000 --> 65750823887641977552896.000 --> 65748537240401513283584.000 --> 69837487700372277428224.000 --> 69836911325663192940544.000 -->
# [[     0 102852]
#  [     1      1]
#  [     2      1]
#  [     3      1]
#  [     4      2]
#  [     5      4]
#  [     6     59]
#  [     7      1]
#  [     8      1]
#  [     9      3]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\bytes-packets_flows\pyts_dataset.npy
# (102925, 31, 2)
# 394678107913385393782784.000 --> 394596708386183527268352.000 --> 260021714830345434562560.000 --> 237123478167447826071552.000 --> 213810178299482876149760.000 --> 64336869556415042158592.000 --> 63989184345260804800512.000 --> 63990824403319801249792.000 --> 63990427404232965488640.000 --> 63999661698530156740608.000 -->
# [[     0 102857]
#  [     1      1]
#  [     2      1]
#  [     3      1]
#  [     4      2]
#  [     5      4]
#  [     6     54]
#  [     7      1]
#  [     8      1]
#  [     9      3]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\bytes_flows-bytes_packets\pyts_dataset.npy
# (102925, 31, 2)
# 19914692944734856.000 --> 6095089581105225.000 --> 6094934592652855.000 --> 6094963158832757.000 --> 6094657635094598.000 --> 6094485662318918.000 --> 6093969334940369.000 --> 6093765579330018.000 --> 6093526928274995.000 --> 6093360950369324.000 -->
# [[     0 102907]
#  [     1      1]
#  [     2      1]
#  [     3      1]
#  [     4      2]
#  [     5      1]
#  [     6      2]
#  [     7      2]
#  [     8      7]
#  [     9      1]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\bytes_flows-flows_(bytes_packets)\pyts_dataset.npy
# (102925, 31, 2)
# 19883263852810356.000 --> 6068462548347330.000 --> 6068145121066017.000 --> 6067827448961713.000 --> 6067489695660260.000 --> 6067006382497562.000 --> 6066370861142326.000 --> 6065789303170343.000 --> 6065399634665717.000 --> 6064269249483118.000 -->
# [[     0 102907]
#  [     1      1]
#  [     2      1]
#  [     3      1]
#  [     4      2]
#  [     5      1]
#  [     6      2]
#  [     7      2]
#  [     8      7]
#  [     9      1]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\bytes_flows-nodes\pyts_dataset.npy
# (102925, 31, 2)
# 20119514142749584.000 --> 6302245047722427.000 --> 6301897198420536.000 --> 6301568364356460.000 --> 6301162336611860.000 --> 6300717139758297.000 --> 6300314788791515.000 --> 6299795732633756.000 --> 6299165656107619.000 --> 6298788612502291.000 -->
# [[     0 102907]
#  [     1      1]
#  [     2      1]
#  [     3      1]
#  [     4      2]
#  [     5      1]
#  [     6      2]
#  [     7      2]
#  [     8      7]
#  [     9      1]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\bytes_packets-flows_(bytes_packets)\pyts_dataset.npy
# (102925, 31, 2)
# 2643304854.703 --> 1277361548.567 --> 1143128762.914 --> 1104434920.800 --> 1114616710.736 --> 1098589180.955 --> 1074001827.823 --> 1083237032.293 --> 1084619745.149 --> 1085605760.571 -->
# [[    0 91950]
#  [    1    68]
#  [    2  1131]
#  [    3    44]
#  [    4    61]
#  [    5   231]
#  [    6    39]
#  [    7  9138]
#  [    8    30]
#  [    9   233]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\bytes_packets-nodes\pyts_dataset.npy
# (102925, 31, 2)
# 244288264588.890 --> 94164354347.347 --> 65850664428.343 --> 67869177029.527 --> 70095170585.251 --> 71270149547.044 --> 72867545472.261 --> 73057340632.437 --> 72542512067.396 --> 72527395095.896 -->
# [[     0 101585]
#  [     1      1]
#  [     2      4]
#  [     3   1134]
#  [     4     46]
#  [     5      1]
#  [     6      2]
#  [     7      3]
#  [     8      1]
#  [     9    148]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\flows-bytes_flows\pyts_dataset.npy
# (102925, 31, 2)
# 20119514142749580.000 --> 6301195944498765.000 --> 6300988459605050.000 --> 6300594486153146.000 --> 6300395861796809.000 --> 6300123946768451.000 --> 6299641226442346.000 --> 6299200445839310.000 --> 6298776613422161.000 --> 6298355437909602.000 -->
# [[     0 102907]
#  [     1      1]
#  [     2      1]
#  [     3      1]
#  [     4      2]
#  [     5      1]
#  [     6      2]
#  [     7      2]
#  [     8      7]
#  [     9      1]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\flows-bytes_packets\pyts_dataset.npy
# (102925, 31, 2)
# 244288264588.890 --> 94164382363.333 --> 65850652543.061 --> 67868687201.223 --> 70096719107.995 --> 71272191838.520 --> 72867041425.266 --> 73018479946.243 --> 72511195505.628 --> 72521803968.346 -->
# [[     0 101585]
#  [     1      1]
#  [     2      4]
#  [     3   1134]
#  [     4     46]
#  [     5      1]
#  [     6      2]
#  [     7      3]
#  [     8      1]
#  [     9    148]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\flows-flows_(bytes_packets)\pyts_dataset.npy
# (102925, 31, 2)
# 10630374421.528 --> 2439422339.684 --> 2313206794.910 --> 2332992216.534 --> 2434617060.890 --> 2455272343.950 --> 2509419898.649 --> 2549339805.726 --> 2510303086.688 --> 2478365293.681 -->
# [[     0 102566]
#  [     1      1]
#  [     2      2]
#  [     3      1]
#  [     4     38]
#  [     5      1]
#  [     6      2]
#  [     7     15]
#  [     8      3]
#  [     9    296]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\flows-nodes\pyts_dataset.npy
# (102925, 31, 2)
# 42384864835.232 --> 9763036657.752 --> 9223908171.017 --> 9212043105.868 --> 9537774562.807 --> 9893152566.040 --> 10308163686.124 --> 10116695579.634 --> 10121232795.478 --> 10125774570.055 -->
# [[     0 102571]
#  [     1      1]
#  [     2      2]
#  [     3      1]
#  [     4     38]
#  [     5      1]
#  [     6      2]
#  [     7     15]
#  [     8      3]
#  [     9    291]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\flows-packets_flows\pyts_dataset.npy
# (102925, 31, 2)
# 85511908279.512 --> 29179990788.190 --> 28879538945.702 --> 27270592638.475 --> 24672643897.895 --> 23997292018.851 --> 24069912117.205 --> 24132711271.182 --> 24217875965.127 --> 24345476000.391 -->
# [[     0 102594]
#  [     1      3]
#  [     2      1]
#  [     3      5]
#  [     4      1]
#  [     5      9]
#  [     6      1]
#  [     7     33]
#  [     8      5]
#  [     9    273]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\flows_(bytes_packets)-nodes\pyts_dataset.npy
# (102925, 31, 2)
# 10630374421.528 --> 2439422233.478 --> 2313206712.037 --> 2332992637.730 --> 2434615530.206 --> 2455270718.884 --> 2509414208.740 --> 2549324285.325 --> 2510297541.578 --> 2478359467.726 -->
# [[     0 102566]
#  [     1      1]
#  [     2      2]
#  [     3      1]
#  [     4     38]
#  [     5      1]
#  [     6      2]
#  [     7     15]
#  [     8      3]
#  [     9    296]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\packets-bytes\pyts_dataset.npy
# (102925, 31, 2)
# 394679157688636161392640.000 --> 394678394974231750246400.000 --> 110795331385941886500864.000 --> 94389482929994277584896.000 --> 94241861087162997407744.000 --> 94241690254271578112000.000 --> 94241525347394068152320.000 --> 94241336824218225999872.000 --> 94238429511385861849088.000 --> 94238207110652547301376.000 -->
# [[     0 102853]
#  [     1      1]
#  [     2      1]
#  [     3      1]
#  [     4      2]
#  [     5      4]
#  [     6     58]
#  [     7      1]
#  [     8      1]
#  [     9      3]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\packets-bytes_flows\pyts_dataset.npy
# (102925, 31, 2)
# 23297370546491596.000 --> 9444202663828012.000 --> 9434577664028204.000 --> 9426150093295494.000 --> 9419281189038198.000 --> 9413730931642350.000 --> 9409582571069110.000 --> 9406505935187204.000 --> 9404571478109022.000 --> 9403623981204356.000 -->
# [[     0 102907]
#  [     1      1]
#  [     2      1]
#  [     3      1]
#  [     4      2]
#  [     5      1]
#  [     6      2]
#  [     7      2]
#  [     8      7]
#  [     9      1]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\packets-bytes_packets\pyts_dataset.npy
# (102925, 31, 2)
# 1414565670595.484 --> 546784177879.726 --> 505572421999.448 --> 528730358211.383 --> 581247604096.754 --> 598972707326.045 --> 620257754998.254 --> 587932989703.592 --> 606331153178.796 --> 594779630483.085 -->
# [[     0 102337]
#  [     1      2]
#  [     2      2]
#  [     3      1]
#  [     4     59]
#  [     5    508]
#  [     6      2]
#  [     7      5]
#  [     8      1]
#  [     9      8]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\packets-flows\pyts_dataset.npy
# (102925, 31, 2)
# 2014261377521.321 --> 700039801125.282 --> 635390131141.823 --> 602726581464.308 --> 605439432264.819 --> 608754589161.592 --> 586029909506.051 --> 583103876878.833 --> 551746781222.703 --> 559241541680.392 -->
# [[     0 102769]
#  [     1      1]
#  [     2      6]
#  [     3      1]
#  [     4      1]
#  [     5     22]
#  [     6      1]
#  [     7      1]
#  [     8    122]
#  [     9      1]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\packets-flows_(bytes_packets)\pyts_dataset.npy
# (102925, 31, 2)
# 307883716102.654 --> 79023768979.207 --> 75029704549.133 --> 75852862537.035 --> 76609145926.845 --> 77544805001.547 --> 76731704352.161 --> 76745779299.272 --> 76760655074.596 --> 76782831556.006 -->
# [[     0 102710]
#  [     1      1]
#  [     2      2]
#  [     3      1]
#  [     4     24]
#  [     5      3]
#  [     6    171]
#  [     7      5]
#  [     8      1]
#  [     9      7]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\packets-nodes\pyts_dataset.npy
# (102925, 31, 2)
# 2014261377521.321 --> 700039801125.282 --> 635390131141.823 --> 602726581464.308 --> 605439432264.819 --> 608754589161.592 --> 586029909506.051 --> 583103876878.833 --> 551746781222.703 --> 559241541680.392 -->
# [[     0 102769]
#  [     1      1]
#  [     2      6]
#  [     3      1]
#  [     4      1]
#  [     5     22]
#  [     6      1]
#  [     7      1]
#  [     8    122]
#  [     9      1]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\packets-packets_flows\pyts_dataset.npy
# (102925, 31, 2)
# 703293396862.202 --> 312887975926.588 --> 287598864897.669 --> 298969469999.010 --> 328522379159.856 --> 330152751554.899 --> 331894296863.333 --> 333702943776.148 --> 335544571836.312 --> 337001770263.011 -->
# [[     0 102828]
#  [     1      1]
#  [     2      2]
#  [     3      1]
#  [     4      1]
#  [     5     79]
#  [     6      3]
#  [     7      5]
#  [     8      1]
#  [     9      4]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\packets_flows-bytes_flows\pyts_dataset.npy
# (102925, 31, 2)
# 19886234881032604.000 --> 6071405049814617.000 --> 6071638463028770.000 --> 6071462182080557.000 --> 6071171270728045.000 --> 6070966039279036.000 --> 6070893888006006.000 --> 6070685904420670.000 --> 6070713333586184.000 --> 6070354763270466.000 -->
# [[     0 102907]
#  [     1      1]
#  [     2      1]
#  [     3      1]
#  [     4      2]
#  [     5      1]
#  [     6      2]
#  [     7      2]
#  [     8      7]
#  [     9      1]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\packets_flows-bytes_packets\pyts_dataset.npy
# (102925, 31, 2)
# 13265141962.711 --> 3889520923.617 --> 3293180885.160 --> 2897848811.205 --> 2778380745.600 --> 2809914404.742 --> 2777527623.911 --> 2838338363.874 --> 2872171721.274 --> 2923303662.250 -->
# [[    0 97733]
#  [    1     1]
#  [    2   459]
#  [    3     1]
#  [    4    89]
#  [    5     2]
#  [    6  4440]
#  [    7    62]
#  [    8     5]
#  [    9   133]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\packets_flows-flows_(bytes_packets)\pyts_dataset.npy
# (102925, 31, 2)
# 15656893.867 --> 3739599.615 --> 3189114.647 --> 3263348.885 --> 3289841.117 --> 3287652.880 --> 3286497.825 --> 3285448.707 --> 3285593.788 --> 3285434.760 -->
# [[     0 102884]
#  [     1      1]
#  [     2      1]
#  [     3      2]
#  [     4      2]
#  [     5      1]
#  [     6      1]
#  [     7     31]
#  [     8      1]
#  [     9      1]]
# interval30_reconstructed_STL_trend_ts_feature/200702111400\packets_flows-nodes\pyts_dataset.npy
# (102925, 31, 2)
# 85511908279.512 --> 29179989578.838 --> 28879409660.029 --> 27270659777.489 --> 24669307265.936 --> 23987070563.900 --> 24065521265.166 --> 24134777318.112 --> 24219558737.964 --> 24344442411.540 -->
# [[     0 102594]
#  [     1      3]
#  [     2      1]
#  [     3      5]
#  [     4      1]
#  [     5      9]
#  [     6      1]
#  [     7     33]
#  [     8      5]
#  [     9    273]]
